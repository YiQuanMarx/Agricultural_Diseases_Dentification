# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.loadtxt('./18-Dec-at-12-54-42_val_acc.txt', delimiter=',')
data = data.tolist()

# %%
data
# Out:
# [0.6023094605813508,
#  0.630192732713502,
#  0.6693490951531416,
#  0.7154771316368729,
#  0.6921480215095552,
#  0.7095764404642357,
#  0.6904991807291636,
#  0.6860223458244319,
#  0.7398615606191348,
#  0.7368252086187314,
#  0.7459869342648578,
#  0.6907196863261776,
#  0.7557432061505366,
#  0.717587282519626,
#  0.7311737434175063,
#  0.7575141768898586,
#  0.7442777788810433,
#  0.753807671771846,
#  0.7457844599440628,
#  0.7295139840433738,
#  0.7378283327564349,
#  0.7502231745465576,
#  0.7570170537371038,
#  0.7274956978336578,
#  0.718594769446127,
#  0.7355027928622484,
#  0.7488445739981635,
#  0.7452350656685897,
#  0.6895501827728832,
#  0.727986735531646,
#  0.7148525933270394,
#  0.748710782684203,
#  0.739618148859158,
#  0.7406427524208662,
#  0.7353115812158635,
#  0.7020078935621851,
#  0.7634980748875064,
#  0.756424712062614,
#  0.7740487031927388,
#  0.7696945507629553,
#  0.7402614264236071,
#  0.7630778586110438,
#  0.7722298889121023,
# ...

# %%
x = np.linspace(0, 30, 30)  # Sample data.
plt.figure(figsize=(6, 4), layout='constrained')
plt.plot(x, data[:30], label='linear')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title("val_acc")
# plt.legend()
# Out:
# Text(0.5, 1.0, 'val_acc')

# %%
import seaborn as sns
# sns.displot(data)
# fig, ax=plt.subplots(figsize=(5, 2.7), layout='constrained')
# ax.scatter(data=data)
# plt.plot(data)
x = np.linspace(0, 300, 300)  # Sample data.
plt.figure(figsize=(6, 4), layout='constrained')
plt.plot(x, data, label='linear')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title("val_acc")
# plt.savefig('./efficient_b3_model_300.jpg')
# plt.legend()

# %%
max(data)
# Out:
# 0.7848780459215797

# %%
import matplotlib.pyplot as plt
import numpy as np

data_test = np.loadtxt('./18-Dec-at-12-54-42_train_loss.txt', delimiter=',')
data_test = data_test.tolist()
x = np.linspace(0, 300, 300)  # Sample data.
plt.figure(figsize=(6, 4), layout='constrained')
plt.plot(x, data_test[:300], label='linear')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title("val_acc")
plt.savefig('./test_efficient_b3_model_300.jpg')

# %%
fig, axs = plt.subplots(2, 1, layout='constrained')
data_train = np.loadtxt('./18-Dec-at-12-54-42_val_acc.txt', delimiter=',')
data_train = data_train.tolist()
x = np.linspace(0, 300, 300)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1].plot(x, data_train)
axs[1].set_title('test_acc_efficient_b3_model_300.jpg')
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('acc')


data_test = np.loadtxt('./18-Dec-at-12-54-42_train_loss.txt', delimiter=',')
data_test = data_test.tolist()
x1 = np.linspace(0, 300, 300)  # Sample data.
axs[0].plot(x1, data_test)
axs[0].set_title('train_loss_efficient_b3_model_300.jpg')
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('loss')
plt.savefig('./efficient_b3_model_300_all.jpg')

# %%
a=[0.591103128456116,0.6750238096150549,0.6558203735826877,0.688446095955187,0.6829163641290601,0.7097993311534571,0.6899549673711742,0.7302928336507669,0.7138346838936007,0.7086161185099323,0.7497506533227878,0.7826970999933556,0.7543371484621896,0.7451861036632121,0.7538071526820157,0.738583222570065,0.7296719467297499,0.742020189489442,0.7353248480681268,0.7198460018639777,0.7542246930705672,0.7210909248063913,0.7706575566025318,0.7437705744984402,0.7494076930503738,0.7508371415224264,0.6879522768889539,0.7518979415962145,0.6904381792162286,0.7262919492613993,0.697388599242181,0.7423114416900429,0.7463675241633152,0.7216774060373323,0.7727208031454316,0.7371896597052298,0.7104504384140169,0.7136342493686962,0.7318215081754829,0.7241083638320283,0.734177027781125,0.7518775836748121,0.6992477929285604
]
plt.plot(a)

# %%
import matplotlib.pyplot as plt
import numpy as np
data1 = np.loadtxt('./20-Dec-at-03-49-37_val_acc.txt', delimiter=',')
data1 = data1.tolist()
x = np.linspace(0, 300, 300)  # Sample data.
plt.figure(figsize=(6, 4), layout='constrained')
plt.plot(x, data1[:300], label='linear')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title("val_acc")
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2.jpg')
#
# fig, ax = plt.subplots(figsize=(5, 2.7))
# ax.plot(np.arange(len(data1)), data1,label='data1')
# ax.legend();

# %%
import matplotlib.pyplot as plt
import numpy as np
data1_tra = np.loadtxt('./20-Dec-at-03-49-37_train_loss.txt', delimiter=',')
data1_tra = data1_tra.tolist()
x = np.linspace(0, 300, 300)  # Sample data.
plt.figure(figsize=(6, 4), layout='constrained')
plt.plot(x, data1_tra[:300], label='linear')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title("val_acc")
plt.savefig('./test_efficient_b3_ASGD_model_300_dropout_l1_l2.jpg')

# %%
fig, axs = plt.subplots(2, 1, layout='constrained')
data_train = np.loadtxt('./20-Dec-at-03-49-37_val_acc.txt', delimiter=',')
data_train = data_train.tolist()
x1 = np.linspace(0, 300, 300)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1].plot(x1, data_train[:300])
axs[1].set_title('test_acc_b3_ASGD_model_300_dropout_l1_l2')
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('acc')


data_test = np.loadtxt('./20-Dec-at-03-49-37_train_loss.txt', delimiter=',')
data_test = data_test.tolist()
x2 = np.linspace(0, 300, 300)  # Sample data.
axs[0].plot(x2, data_test[:300])
axs[0].set_title('train_loss_b3_ASGD_model_300_dropout_l1_l2')
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('loss')
plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

# %%
max(data_train)
# Out:
# 0.7848780459215797

# %%
fig, axs = plt.subplots(2, 1, layout='constrained')
data_train = np.loadtxt('./20-Dec-at-16-44-15_train_acc.txt', delimiter=',')
data_train = data_train.tolist()
x1 = np.linspace(0, 59, 59)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1].plot(x1, data_train)
axs[1].set_title('test_acc_b3_adam_model_59_dropout_l1_l2')
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('acc')


data_test = np.loadtxt('./20-Dec-at-16-44-15_train_loss.txt', delimiter=',')
data_test = data_test.tolist()
x2 = np.linspace(0, 59, 59)  # Sample data.
axs[0].plot(x2, data_test)
axs[0].set_title('train_loss_b3_adam_model_59_dropout_l1_l2')
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('loss')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')
# Out:
# Text(0, 0.5, 'loss')

# %%
fig, axs = plt.subplots(2, 1, layout='constrained')
data_train = np.loadtxt('./20-Dec-at-16-44-15_val_acc.txt', delimiter=',')
data_train = data_train.tolist()
x1 = np.linspace(0, 59, 59)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1].plot(x1, data_train)
axs[1].set_title('test_acc_b3_adam_model_59_dropout_l1_l2')
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('acc')


data_test = np.loadtxt('./20-Dec-at-16-44-15_val_loss.txt', delimiter=',')
data_test = data_test.tolist()
x2 = np.linspace(0, 59, 59)  # Sample data.
axs[0].plot(x2, data_test)
axs[0].set_title('train_loss_b3_adam_model_59_dropout_l1_l2')
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('loss')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')
# Out:
# Text(0, 0.5, 'loss')

# %%
fig, axs = plt.subplots(2, 1, layout='constrained')
data_train = np.loadtxt('./20-Dec-at-17-14-59_train_acc.txt', delimiter=',')
data_train = data_train.tolist()
x1 = np.linspace(0, 11, 11)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1].plot(x1, data_train)
axs[1].set_title('train_acc_b3_RMSprop_model_11_dropout_0.1')
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('acc')


data_test = np.loadtxt('./20-Dec-at-17-14-59_train_loss.txt', delimiter=',')
data_test = data_test.tolist()
x2 = np.linspace(0, 11, 11)  # Sample data.
axs[0].plot(x2, data_test)
axs[0].set_title('train_loss_b3_RMSprop_model_11_dropout_0.1')
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('loss')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')
# Out:
# Text(0, 0.5, 'loss')

# %%
fig, axs = plt.subplots(2, 1, layout='constrained')
data_train = np.loadtxt('./20-Dec-at-17-14-59_val_acc.txt', delimiter=',')
data_train = data_train.tolist()
x1 = np.linspace(0, 11, 11)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1].plot(x1, data_train)
axs[1].set_title('val_acc_b3_RMSprop_model_11_dropout_0.1')
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('acc')


data_test = np.loadtxt('./20-Dec-at-17-14-59_val_loss.txt', delimiter=',')
data_test = data_test.tolist()
x2 = np.linspace(0, 11, 11)  # Sample data.
axs[0].plot(x2, data_test)
axs[0].set_title('val_loss_b3_RMSprop_model_11_dropout_0.1')
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('loss')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')
# Out:
# Text(0, 0.5, 'loss')

# %%
fig, axs = plt.subplots(2, 2, layout='constrained')
data_train_loss = np.loadtxt('../log/efficient_b3_ASGD_lr0.001_l20.01_drop0.8/21-Dec-at-06-37-50_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 100, 100)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss)
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')


data_train_acc = np.loadtxt('../log/efficient_b3_ASGD_lr0.001_l20.01_drop0.8/21-Dec-at-06-37-50_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 100, 100)  # Sample data.
axs[0,1].plot(x2, data_train_acc)
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/efficient_b3_ASGD_lr0.001_l20.01_drop0.8/21-Dec-at-06-37-50_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 100, 100)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].plot(x3, data_test_loss)
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/efficient_b3_ASGD_lr0.001_l20.01_drop0.8/21-Dec-at-06-37-50_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 100, 100)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val)
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')

# %%
fig, axs = plt.subplots(2, 2, layout='constrained')
data_train_loss = np.loadtxt('../log/efficient_b3_ASGD_lr0.001_l20.01_drop0.8/21-Dec-at-06-37-50_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 18, 18)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss[:18])
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')


data_train_acc = np.loadtxt('../log/efficient_b3_ASGD_lr0.001_l20.01_drop0.8/21-Dec-at-06-37-50_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 18, 18)  # Sample data.
axs[0,1].plot(x2, data_train_acc[:18])
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/efficient_b3_ASGD_lr0.001_l20.01_drop0.8/21-Dec-at-06-37-50_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 18, 18)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].plot(x3, data_test_loss[:18])
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/efficient_b3_ASGD_lr0.001_l20.01_drop0.8/21-Dec-at-06-37-50_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 18, 18)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val[:18])
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')
