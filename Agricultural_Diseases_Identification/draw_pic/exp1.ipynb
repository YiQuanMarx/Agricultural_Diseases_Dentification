# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import seaborn as sns

sns.set_theme()
# fig, axs = plt.subplots(2, 2, layout='constrained')
fig, axs = plt.subplots(2, 2, figsize=(20, 12),layout='constrained',dpi=200)
x1 = np.linspace(0, 300, 300) # Sample data.
Adadelta_train_loss = np.loadtxt('../log/exp1/alex/alex_train_loss.txt', delimiter=',')
eff2_train_loss = np.loadtxt('../log/exp1/eff2/eff2_train_loss.txt', delimiter=',')
eff3_train_loss = np.loadtxt('../log/exp1/eff3/eff3_train_loss.txt', delimiter=',')
eff7_train_loss = np.loadtxt('../log/exp1/eff7/eff7_train_loss.txt', delimiter=',')
mob2_train_loss = np.loadtxt('../log/exp1/mob2/mob2_train_loss.txt', delimiter=',')
mob3_train_loss = np.loadtxt('../log/exp1/mob3/mob3_train_loss.txt', delimiter=',')
re50_train_loss = np.loadtxt('../log/exp1/re50/re50_train_loss.txt', delimiter=',')
alex_train_loss = np.loadtxt('../log/exp1/alex/alex_train_loss.txt', delimiter=',')
vg19_train_loss = np.loadtxt('../log/exp1/vg19/vg19_train_loss.txt', delimiter=',')
# axe[0,0].set_xlim([xmin,xmax])
# axes = plt.gca()
axs[0,0].set_ylim(30,120)
axs[0,0].plot(x1, vg19_train_loss ,label='vg19')
axs[0,0].plot(x1, alex_train_loss ,label='alex')
axs[0,0].plot(x1, re50_train_loss ,label='re50')
axs[0,0].plot(x1, mob3_train_loss ,label='mob3')
axs[0,0].plot(x1, mob2_train_loss ,label='mob2')
axs[0,0].plot(x1, eff7_train_loss ,label='eff7')
axs[0,0].plot(x1, eff3_train_loss ,label='eff3')
axs[0,0].plot(x1, eff2_train_loss ,label='eff2',linestyle='--')

axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')

x2 = np.linspace(0, 300, 300) # Sample data.
alex_train_acc = np.loadtxt('../log/exp1/alex/alex_train_acc.txt', delimiter=',')
eff2_train_acc = np.loadtxt('../log/exp1/eff2/eff2_train_acc.txt', delimiter=',')
eff3_train_acc = np.loadtxt('../log/exp1/eff3/eff3_train_acc.txt', delimiter=',')
eff7_train_acc = np.loadtxt('../log/exp1/eff7/eff7_train_acc.txt', delimiter=',')
mob2_train_acc = np.loadtxt('../log/exp1/mob2/mob2_train_acc.txt', delimiter=',')
mob3_train_acc = np.loadtxt('../log/exp1/mob3/mob3_train_acc.txt', delimiter=',')
re50_train_acc = np.loadtxt('../log/exp1/re50/re50_train_acc.txt', delimiter=',')
vg19_train_acc = np.loadtxt('../log/exp1/vg19/vg19_train_acc.txt', delimiter=',')
axs[0,1].set_ylim(0.6,0.95)
axs[0,1].plot(x2, vg19_train_acc,label='vg19')
axs[0,1].plot(x2, alex_train_acc,label='alex')
axs[0,1].plot(x2, re50_train_acc,label='re50')
axs[0,1].plot(x2, mob3_train_acc,label='mob3')
axs[0,1].plot(x2, mob2_train_acc,label='mob2')
axs[0,1].plot(x2, eff7_train_acc,label='eff7')
axs[0,1].plot(x2, eff3_train_acc,label='eff3')
axs[0,1].plot(x2, eff2_train_acc,label='eff2',linestyle='--')
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_mob2_model_300_dropout_l1_l2_all.jpg')

x3 = np.linspace(0, 300, 300) # Sample data.
eff2_test_loss = np.loadtxt('../log/exp1/eff2/eff2_val_loss.txt', delimiter=',')
eff3_test_loss = np.loadtxt('../log/exp1/eff3/eff3_val_loss.txt', delimiter=',')
eff7_test_loss = np.loadtxt('../log/exp1/eff7/eff7_val_loss.txt', delimiter=',')
mob2_test_loss = np.loadtxt('../log/exp1/mob2/mob2_val_loss.txt', delimiter=',')
mob3_test_loss = np.loadtxt('../log/exp1/mob3/mob3_val_loss.txt', delimiter=',')
re50_test_loss = np.loadtxt('../log/exp1/re50/re50_val_loss.txt', delimiter=',')
alex_test_loss = np.loadtxt('../log/exp1/alex/alex_val_loss.txt', delimiter=',')
vg19_test_loss = np.loadtxt('../log/exp1/vg19/vg19_val_loss.txt', delimiter=',')
axs[1,0].set_ylim(75,250)
axs[1,0].plot(x3, vg19_test_loss,label='vg19')
axs[1,0].plot(x3, alex_test_loss,label='alex')
axs[1,0].plot(x3, re50_test_loss,label='re50')
axs[1,0].plot(x3, mob3_test_loss,label='mob3')
axs[1,0].plot(x3, mob2_test_loss,label='mob2')
axs[1,0].plot(x3, eff7_test_loss,label='eff7')
axs[1,0].plot(x3, eff3_test_loss,label='eff3')
axs[1,0].plot(x3, eff2_test_loss,label='eff2',linestyle='--')
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

x4 = np.linspace(0,300, 300) # Sample data.
eff2_test_val = np.loadtxt('../log/exp1/eff2/eff2_val_acc.txt', delimiter=',')
eff3_test_val = np.loadtxt('../log/exp1/eff3/eff3_val_acc.txt', delimiter=',')
eff7_test_val = np.loadtxt('../log/exp1/eff7/eff7_val_acc.txt', delimiter=',')
mob2_test_val = np.loadtxt('../log/exp1/mob2/mob2_val_acc.txt', delimiter=',')
mob3_test_val = np.loadtxt('../log/exp1/mob3/mob3_val_acc.txt', delimiter=',')
re50_test_val = np.loadtxt('../log/exp1/re50/re50_val_acc.txt', delimiter=',')
alex_test_val = np.loadtxt('../log/exp1/alex/alex_val_acc.txt', delimiter=',')
vg19_test_val = np.loadtxt('../log/exp1/vg19/vg19_val_acc.txt', delimiter=',')
axs[1,1].set_ylim(0.6,0.85)
axs[1,1].plot(x4, vg19_test_val,label='vg19')
axs[1,1].plot(x4, alex_test_val,label='alex')
axs[1,1].plot(x4, re50_test_val,label='re50')
axs[1,1].plot(x4, mob3_test_val,label='mob3')
axs[1,1].plot(x4, mob2_test_val,label='mob2')
axs[1,1].plot(x4, eff7_test_val,label='eff7')
axs[1,1].plot(x4, eff3_test_val,label='eff3')
axs[1,1].plot(x4, eff2_test_val,label='eff2',linestyle='-')
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')

#初始化labels和线型数组
lines=[]
labels=[]
# 通过循环获取线型和labels
# for ax in fig.axes:
axLine, axLabel = ax.get_legend_handles_labels()
lines.extend(axLine)
labels.extend(axLabel)
# 设置图例和调整图例位置
plt.subplots_adjust(wspace=5,hspace=5)
fig.legend(lines, labels,loc=3,bbox_to_anchor=(1.01, 0.3),
           ncol=1,framealpha=False,fontsize=20)

# https://blog.csdn.net/m0_53115174/article/details/123008276?spm=1001.2101.3001.6650.5&utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7ERate-5-123008276-blog-121574695.pc_relevant_3mothn_strategy_recovery&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7ERate-5-123008276-blog-121574695.pc_relevant_3mothn_strategy_recovery&utm_relevant_index=10
# https://blog.csdn.net/Poul_henry/article/details/82533569
# 线型：https://blog.csdn.net/HHG20171226/article/details/101422518
# Out:
# /tmp/ipykernel_93948/3685008332.py:111: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(wspace=5,hspace=5)
