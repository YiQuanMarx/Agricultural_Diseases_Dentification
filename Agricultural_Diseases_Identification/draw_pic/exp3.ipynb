# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import seaborn as sns

sns.set_theme()
# fig, axs = plt.subplots(2, 2, layout='constrained')
fig, axs = plt.subplots(2, 2, figsize=(20, 12),layout='constrained',dpi=200)
x1 = np.linspace(0, 300, 300) # Sample data.
eight_batch_train_loss = np.loadtxt('../log/exp3/8batch/8batch_train_loss.txt', delimiter=',')
four_batch_train_loss = np.loadtxt('../log/exp3/4batch/4batch_train_loss.txt', delimiter=',')
twelve_batch_train_loss = np.loadtxt('../log/exp3/12batch/12batch_train_loss.txt', delimiter=',')
sixteen_batch_train_loss = np.loadtxt('../log/exp3/16batch/16batch_train_loss.txt', delimiter=',')
twenty_batch_train_loss = np.loadtxt('../log/exp3/20batch/20batch_train_loss.txt', delimiter=',')
twentyfour_batch_train_loss = np.loadtxt('../log/exp3/24batch/24batch_train_loss.txt', delimiter=',')
twentyeghit_batch_train_loss = np.loadtxt('../log/exp3/28batch/28batch_train_loss.txt', delimiter=',')
thirtytwo_batch_train_loss = np.loadtxt('../log/exp3/32batch/32batch_train_loss.txt', delimiter=',')
# axe[0,0].set_xlim([xmin,xmax])
# axes = plt.gca()
axs[0,0].set_ylim(0,350)
axs[0,0].plot(x1, thirtytwo_batch_train_loss ,label='32batch')
axs[0,0].plot(x1, twentyeghit_batch_train_loss ,label='28batch')
axs[0,0].plot(x1, twentyfour_batch_train_loss ,label='24batch')
axs[0,0].plot(x1, twenty_batch_train_loss ,label='20batch')
axs[0,0].plot(x1, sixteen_batch_train_loss ,label='16batch')
axs[0,0].plot(x1, twelve_batch_train_loss ,label='12batch')
axs[0,0].plot(x1, eight_batch_train_loss ,label='8batch')
axs[0,0].plot(x1, four_batch_train_loss ,label='4batch',linestyle='--')

axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')

x2 = np.linspace(0, 300, 300) # Sample data.
eight_batch_train_acc = np.loadtxt('../log/exp3/8batch/8batch_train_acc.txt', delimiter=',')
four_batch_train_acc = np.loadtxt('../log/exp3/4batch/4batch_train_acc.txt', delimiter=',')
twelve_batch_train_acc = np.loadtxt('../log/exp3/12batch/12batch_train_acc.txt', delimiter=',')
sixteen_batch_train_acc = np.loadtxt('../log/exp3/16batch/16batch_train_acc.txt', delimiter=',')
twenty_batch_train_acc = np.loadtxt('../log/exp3/20batch/20batch_train_acc.txt', delimiter=',')
twentyfour_batch_train_acc = np.loadtxt('../log/exp3/24batch/24batch_train_acc.txt', delimiter=',')
twentyeghit_batch_train_acc = np.loadtxt('../log/exp3/28batch/28batch_train_acc.txt', delimiter=',')
thirtytwo_batch_train_acc = np.loadtxt('../log/exp3/32batch/32batch_train_acc.txt', delimiter=',')
axs[0,1].set_ylim(0.7,0.95)
axs[0,1].plot(x2, thirtytwo_batch_train_acc,label='32batch')
axs[0,1].plot(x2, twentyeghit_batch_train_acc,label='28batch')
axs[0,1].plot(x2, twentyfour_batch_train_acc,label='24batch')
axs[0,1].plot(x2, twenty_batch_train_acc,label='20batch')
axs[0,1].plot(x2, sixteen_batch_train_acc,label='16batch')
axs[0,1].plot(x2, twelve_batch_train_acc,label='12batch')
axs[0,1].plot(x2, eight_batch_train_acc,label='8batch')
axs[0,1].plot(x2, four_batch_train_acc,label='4batch',linestyle='--')
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_20batch_model_300_dropout_l1_l2_all.jpg')

x3 = np.linspace(0, 300, 300) # Sample data.
eight_batch_test_loss = np.loadtxt('../log/exp3/8batch/8batch_val_loss.txt', delimiter=',')
four_batch_test_loss = np.loadtxt('../log/exp3/4batch/4batch_val_loss.txt', delimiter=',')
twelve_batch_test_loss = np.loadtxt('../log/exp3/12batch/12batch_val_loss.txt', delimiter=',')
sixteen_batch_test_loss = np.loadtxt('../log/exp3/16batch/16batch_val_loss.txt', delimiter=',')
twenty_batch_test_loss = np.loadtxt('../log/exp3/20batch/20batch_val_loss.txt', delimiter=',')
twentyfour_batch_test_loss = np.loadtxt('../log/exp3/24batch/24batch_val_loss.txt', delimiter=',')
twentyeghitbatch_test_loss = np.loadtxt('../log/exp3/28batch/28batch_val_loss.txt', delimiter=',')
thirtytwo_batch_test_loss = np.loadtxt('../log/exp3/32batch/32batch_val_loss.txt', delimiter=',')
axs[1,0].set_ylim(0,400)
axs[1,0].plot(x3, thirtytwo_batch_test_loss,label='32batch')
axs[1,0].plot(x3, twentyeghitbatch_test_loss,label='28batch')
axs[1,0].plot(x3, twentyfour_batch_test_loss,label='24batch')
axs[1,0].plot(x3, twenty_batch_test_loss,label='20batch')
axs[1,0].plot(x3, sixteen_batch_test_loss,label='16batch')
axs[1,0].plot(x3, twelve_batch_test_loss,label='12batch')
axs[1,0].plot(x3, eight_batch_test_loss,label='8batch')
axs[1,0].plot(x3, four_batch_test_loss,label='4batch',linestyle='--')
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

x4 = np.linspace(0,300, 300) # Sample data.
eight_batch_test_val = np.loadtxt('../log/exp3/8batch/8batch_val_acc.txt', delimiter=',')
four_batch_test_val = np.loadtxt('../log/exp3/4batch/4batch_val_acc.txt', delimiter=',')
twelve_batch_test_val = np.loadtxt('../log/exp3/12batch/12batch_val_acc.txt', delimiter=',')
sixteen_batch_test_val = np.loadtxt('../log/exp3/16batch/16batch_val_acc.txt', delimiter=',')
twenty_batch_test_val = np.loadtxt('../log/exp3/20batch/20batch_val_acc.txt', delimiter=',')
twentyfour_batch_test_val = np.loadtxt('../log/exp3/24batch/24batch_val_acc.txt', delimiter=',')
twentyeghitbatch_test_val = np.loadtxt('../log/exp3/28batch/28batch_val_acc.txt', delimiter=',')
thirtytwo_batch_test_val = np.loadtxt('../log/exp3/32batch/32batch_val_acc.txt', delimiter=',')
axs[1,1].set_ylim(0.3,0.85)
axs[1,1].plot(x4, thirtytwo_batch_test_val,label='32batch')
axs[1,1].plot(x4, twentyeghitbatch_test_val,label='28batch')
axs[1,1].plot(x4, twentyfour_batch_test_val,label='24batch')
axs[1,1].plot(x4, twenty_batch_test_val,label='20batch')
axs[1,1].plot(x4, sixteen_batch_test_val,label='16batch')
axs[1,1].plot(x4, twelve_batch_test_val,label='12batch')
axs[1,1].plot(x4, eight_batch_test_val,label='8batch',linestyle='solid')
axs[1,1].plot(x4, four_batch_test_val,label='4batch',linestyle='--')
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')

#初始化labels和线型数组
lines=[]
labels=[]
#通过循环获取线型和labels
# for ax in fig.axes:
axLine, axLabel = ax.get_legend_handles_labels()
lines.extend(axLine)
labels.extend(axLabel)
#设置图例和调整图例位置
# plt.subplots_adjust(wspace=5,hspace=5)
fig.legend(lines, labels,loc=3,bbox_to_anchor=(1.01, 0.3),
ncol=1,framealpha=False,fontsize=20)
# https://blog.csdn.net/m0_53115174/article/details/123008276?spm=1001.2101.3001.6650.5&utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7ERate-5-123008276-blog-121574695.pc_relevant_3mothn_strategy_recovery&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7ERate-5-123008276-blog-121574695.pc_relevant_3mothn_strategy_recovery&utm_relevant_index=10
# https://blog.csdn.net/Poul_henry/article/details/82533569
# 线型：https://blog.csdn.net/HHG20171226/article/details/101422518

# %%
fig, axs = plt.subplots(2, 2,figsize=(20, 12), layout='constrained')
data_train_loss = np.loadtxt('../log/exp3/32batch/32batch_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 300, 300)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss)
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')


data_train_acc = np.loadtxt('../log/exp3/32batch/32batch_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 300, 300)  # Sample data.
axs[0,1].plot(x2, data_train_acc)
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/exp3/32batch/32batch_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 300, 300)  # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].set_ylim(20,40)
axs[1,0].plot(x3, data_test_loss)
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/exp3/32batch/32batch_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 300, 300)  # Sample data.
axs[1,1].set_ylim(0.7,0.85)
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val)
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')

# %%
print(max(data_test_val))
print(np.mean(data_test_val))
print(np.std(data_test_val))
print(max(data_test_loss))
print(np.mean(data_test_loss))
print(np.std(data_test_loss))
# Out:
# 0.8222997432252384
# 0.7648583928899224
# 0.053034514408733954
# 112.95847368240356
# 27.393115845719972
# 5.897117150677399

# %%
fig, axs = plt.subplots(2, 2,figsize=(20, 12), layout='constrained')
data_train_loss = np.loadtxt('../log/exp3/28batch/28batch_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss)
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')

data_train_acc = np.loadtxt('../log/exp3/28batch/28batch_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 300, 300) # Sample data.
axs[0,1].plot(x2, data_train_acc)
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/exp3/28batch/28batch_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].set_ylim(20,40)
axs[1,0].plot(x3, data_test_loss)
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/exp3/28batch/28batch_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 300, 300) # Sample data.
axs[1,1].set_ylim(0.7,0.85)
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val)
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')

# %%
print(max(data_test_val))
print(np.mean(data_test_val))
print(np.std(data_test_val))
print(max(data_test_loss))
print(np.mean(data_test_loss))
print(np.std(data_test_loss))
# Out:
# 0.8224500262297239
# 0.7652703895983937
# 0.051400779131753345
# 113.50245475769043
# 31.251158155246326
# 5.800910784012222

# %%
fig, axs = plt.subplots(2, 2,figsize=(20, 12), layout='constrained')
data_train_loss = np.loadtxt('../log/exp3/24batch/24batch_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss)
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')

data_train_acc = np.loadtxt('../log/exp3/24batch/24batch_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 300, 300) # Sample data.
axs[0,1].plot(x2, data_train_acc)
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/exp3/24batch/24batch_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].set_ylim(30,45)
axs[1,0].plot(x3, data_test_loss)
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/exp3/24batch/24batch_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 300, 300) # Sample data.
axs[1,1].set_ylim(0.7,0.85)
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val)
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')

# %%
print(max(data_test_val))
print(np.mean(data_test_val))
print(np.std(data_test_val))
print(max(data_test_loss))
print(np.mean(data_test_loss))
print(np.std(data_test_loss))
# Out:
# 0.817507210983221
# 0.7685416875131896
# 0.044982008608752046
# 117.16605496406555
# 36.63830225800474
# 5.916355932042613

# %%
fig, axs = plt.subplots(2, 2,figsize=(20, 12), layout='constrained')
data_train_loss = np.loadtxt('../log/exp3/20batch/20batch_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss)
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')

data_train_acc = np.loadtxt('../log/exp3/20batch/20batch_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 300, 300) # Sample data.
axs[0,1].plot(x2, data_train_acc)
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/exp3/20batch/20batch_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].set_ylim(30,60)
axs[1,0].plot(x3, data_test_loss)
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/exp3/20batch/20batch_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 300, 300) # Sample data.
axs[1,1].set_ylim(0.7,0.85)
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val)
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')

# %%
print(max(data_test_val))
print(np.mean(data_test_val))
print(np.std(data_test_val))
print(max(data_test_loss))
print(np.mean(data_test_loss))
print(np.std(data_test_loss))
# Out:
# 0.8245161486661137
# 0.7662608082601884
# 0.04069466028428432
# 118.69898509979248
# 44.232101539274055
# 6.209882885123757

# %%
fig, axs = plt.subplots(2, 2,figsize=(20, 12), layout='constrained')
data_train_loss = np.loadtxt('../log/exp3/16batch/16batch_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss)
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')

data_train_acc = np.loadtxt('../log/exp3/16batch/16batch_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 300, 300) # Sample data.
axs[0,1].plot(x2, data_train_acc)
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/exp3/16batch/16batch_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].set_ylim(40,70)
axs[1,0].plot(x3, data_test_loss)
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/exp3/16batch/16batch_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 300, 300) # Sample data.
axs[1,1].set_ylim(0.7,0.85)
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val)
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')

# %%
print(max(data_test_val))
print(np.mean(data_test_val))
print(np.std(data_test_val))
print(max(data_test_loss))
print(np.mean(data_test_loss))
print(np.std(data_test_loss))
# Out:
# 0.8154238948969235
# 0.7684834581024577
# 0.03555663123761925
# 123.97586524486542
# 55.939777131627004
# 6.85294608919345

# %%
fig, axs = plt.subplots(2, 2,figsize=(20, 12), layout='constrained')
data_train_loss = np.loadtxt('../log/exp3/8batch/8batch_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss)
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')

data_train_acc = np.loadtxt('../log/exp3/8batch/8batch_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 300, 300) # Sample data.
axs[0,1].plot(x2, data_train_acc)
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/exp3/8batch/8batch_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].set_ylim(80,180)
axs[1,0].plot(x3, data_test_loss)
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/exp3/8batch/8batch_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 300, 300) # Sample data.
axs[1,1].set_ylim(0.7,0.85)
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val)
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')

# %%
print(max(data_test_val))
print(np.mean(data_test_val))
print(np.std(data_test_val))
print(max(data_test_loss))
print(np.mean(data_test_loss))
print(np.std(data_test_loss))
# Out:
# 0.8179397209431047
# 0.7549206457355516
# 0.032273689084265055
# 178.6129589676857
# 125.19644675405696
# 20.971518147132553

# %%
fig, axs = plt.subplots(2, 2,figsize=(20, 12), layout='constrained')
data_train_loss = np.loadtxt('../log/exp3/12batch/12batch_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss)
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')

data_train_acc = np.loadtxt('../log/exp3/12batch/12batch_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 300, 300) # Sample data.
axs[0,1].plot(x2, data_train_acc)
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/exp3/12batch/12batch_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].set_ylim(60,95)
axs[1,0].plot(x3, data_test_loss)
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/exp3/12batch/12batch_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 300, 300) # Sample data.
axs[1,1].set_ylim(0.7,0.85)
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val)
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')

# %%
print(max(data_test_val))
print(np.mean(data_test_val))
print(np.std(data_test_val))
print(max(data_test_loss))
print(np.mean(data_test_loss))
print(np.std(data_test_loss))
# Out:
# 0.8211507640961235
# 0.7656824456030955
# 0.029623805445954852
# 135.26121866703033
# 76.61899397254766
# 9.009480411302896

# %%
fig, axs = plt.subplots(2, 2,figsize=(20, 4), layout='constrained')
data_train_loss = np.loadtxt('../log/exp3/4batch/4batch_train_loss.txt', delimiter=',')
# data_train_loss = data_train.tolist()
x1 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[0,0].plot(x1, data_train_loss)
axs[0,0].set_title('train_loss')
axs[0,0].set_xlabel('epoch')
axs[0,0].set_ylabel('loss')

data_train_acc = np.loadtxt('../log/exp3/4batch/4batch_train_acc.txt', delimiter=',')
# data_train_acc = data_test.tolist()
x2 = np.linspace(0, 300, 300) # Sample data.
axs[0,1].plot(x2, data_train_acc)
axs[0,1].set_title('train_acc')
axs[0,1].set_xlabel('epoch')
axs[0,1].set_ylabel('acc')
# plt.savefig('./efficient_b3_ASGD_model_300_dropout_l1_l2_all.jpg')

data_test_loss = np.loadtxt('../log/exp3/4batch/4batch_val_loss.txt', delimiter=',')
# data_train = data_train.tolist()
x3 = np.linspace(0, 300, 300) # Sample data.
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,0].set_ylim(60,100)
axs[1,0].plot(x3, data_test_loss)
axs[1,0].set_title('val_loss')
axs[1,0].set_xlabel('epoch')
axs[1,0].set_ylabel('loss')

data_test_val = np.loadtxt('../log/exp3/4batch/4batch_val_acc.txt', delimiter=',')
# data_train = data_train.tolist()
x4 = np.linspace(0, 300, 300) # Sample data.
axs[1,1].set_ylim(0.7,0.85)
# plt.figure(figsize=(6, 4), layout='constrained')
axs[1,1].plot(x4, data_test_val)
axs[1,1].set_title('val_acc')
axs[1,1].set_xlabel('epoch')
axs[1,1].set_ylabel('acc')
# Out:
# Text(0, 0.5, 'acc')

# %%
print(max(data_test_val))
print(np.mean(data_test_val))
print(np.std(data_test_val))
print(max(data_test_loss))
print(np.mean(data_test_loss))
print(np.std(data_test_loss))
# Out:
# 0.7986995104695299
# 0.6419655674314648
# 0.10915745655255173
# 1367.6391754738247
# 367.17273372398535
# 181.91164895181808
